# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristanSanchez/VDA-CPE-031-CPE21S4/blob/main/Exercise_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating Data Frame

# %%
# !pip install pandas

import pandas as PD
data = {
    'apples:':[3,2,0,1],
    'oranges:':[0,3,7,2]
}
purchases = PD.DataFrame(data)
purchases
# Out:
# ...
#    apples:  oranges:
# 0        3         0
# 1        2         3
# 2        0         7
# 3        1         2

# %% [markdown]
# # DataFrame Index

# %%
import pandas as PD

data = {
    'apples:':[3,2,0,1],
    'oranges:':[0,3,7,2]
}

purchases = PD.DataFrame(data, index=['June','Robert','Lily','David'])
purchases
# Out:
#         apples:  oranges:
# June          3         0
# Robert        2         3
# Lily          0         7
# David         1         2

# %% [markdown]
# # Locate - Locate specific record

# %%
import pandas as PD

data = {
    'apples:':[3,2,0,1],
    'oranges:':[0,3,7,2]
}

purchases = PD.DataFrame(data, index=['June','Robert','Lily','David'])
purchases

purchases.loc['June']
# Out:
# apples:     3
# oranges:    0
# Name: June, dtype: int64

# %% [markdown]
# # Importing Data Frame to csv or excel file

# %%
purchases.to_csv('fruits.csv')

#or

purchases.to_excel('fruits.xlsx')

# %% [markdown]
# # Reading Data from csv

# %%
data = pd.read_csv('fruits.csv')

purchases = pd.DataFrame(data)
print(purchases)
# Out:
#   Unnamed: 0  apples:  oranges:
# 0       June        3         0
# 1     Robert        2         3
# 2       Lily        0         7
# 3      David        1         2

# %% [markdown]
# # Loading the data from excel file into DataFrame

# %%
#Loading the data from excel file
data = pd.read_excel("fruits.xlsx")
purchases = pd.DataFrame(data)
print(purchases)
# Out:
#   Unnamed: 0  apples:  oranges:
# 0       June        3         0
# 1     Robert        2         3
# 2       Lily        0         7
# 3      David        1         2

# %% [markdown]
# # DataFrame.tail(n)

# %%
data.tail(3)
# Out:
#   Unnamed: 0  apples:  oranges:
# 1     Robert        2         3
# 2       Lily        0         7
# 3      David        1         2

# %% [markdown]
# # Lab: Creating and Accessing Panda DataFrames

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0cdf860d-665b-40c6-8b1d-e529380f7bb8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0cdf860d-665b-40c6-8b1d-e529380f7bb8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('Car_data - extended_data.csv')

Car_data = pd.DataFrame(data)

Car_data
# Out:
#      model_year          brand                                model  \
# 0          2016         Toyota                    Land Cruiser Base
# 1          2014            RAM  ProMaster 2500 Window Van High Roof
# 2          2002           Ford                           Mustang GT
# 3          2012            BMW              428 Gran Coupe i xDrive
# 4          2008  Mercedes-Benz              SL-Class SL500 Roadster
# ..          ...            ...                                  ...
# 994        2016         Subaru                         WRX STI Base
# 995        2010  Mercedes-Benz                 E-Class E 350 4MATIC
# 996        2016           Audi                 A6 2.0T Premium Plus
# 997        2017  Mercedes-Benz                 C-Class C 300 4MATIC
# 998        2012         Toyota                          4Runner 4WD
#
#             type  miles_per_gallon
# 0            SUV                13
# 1            Van                15
# 2          Coupe                16
# ...

# %%
import pandas as pd

data = {
    'year': [2016, 2014, 2002, 2012, 2008],
    'brand': ['Toyota', 'RAM', 'Ford', 'BMW', 'Mercedes-Benz'],
    'model': ['Land Cruiser Base', 'ProMaster 2500 Window Van High Roof', 'Mustang GT', '428 Gran Coupe i xDrive', 'SL-Class SL500 Roadster Convertible'],
    'type': ['SUV', 'Van', 'Coupe', 'Sedan', 'Convertible'],
    'city_miles_per_gallon': [13, 15, 16, 27, 18],
    'highway_miles_per_gallon': [18, 20, 22, 34, 25]
}


df_dict = pd.DataFrame(data)

df_dict
# Out:
#    year          brand                                model         type  \
# 0  2016         Toyota                    Land Cruiser Base          SUV
# 1  2014            RAM  ProMaster 2500 Window Van High Roof          Van
# 2  2002           Ford                           Mustang GT        Coupe
# 3  2012            BMW              428 Gran Coupe i xDrive        Sedan
# 4  2008  Mercedes-Benz  SL-Class SL500 Roadster Convertible  Convertible
#
#    city_miles_per_gallon  highway_miles_per_gallon
# 0                     13                        18
# 1                     15                        20
# 2                     16                        22
# 3                     27                        34
# 4                     18                        25

# %%
data =[
    {'year': 2016, 'brand': 'Toyota', 'model': 'Land Cruiser Base', 'type': 'SUV', 'city_miles_per_gallon': 13, 'highway_miles_per_gallon': 18},
    {'year': 2014, 'brand': 'RAM', 'model': 'ProMaster 2500 Window Van High Roof', 'type': 'Van', 'city_miles_per_gallon': 15, 'highway_miles_per_gallon': 20},
    {'year': 2002, 'brand': 'Ford', 'model': 'Mustang GT', 'type': 'Coupe', 'city_miles_per_gallon': 16, 'highway_miles_per_gallon': 22},
    {'year': 2012, 'brand': 'BMW', 'model': '428 Gran Coupe i xDrive', 'type': 'Sedan', 'city_miles_per_gallon': 27, 'highway_miles_per_gallon': 34},
    {'year': 2008, 'brand': 'Mercedes-Benz', 'model': 'SL-Class SL500 Roadster Convertible', 'type': 'Convertible', 'city_miles_per_gallon': 18, 'highway_miles_per_gallon': 25}
]


import pandas as pd


df_list = pd.DataFrame(data)


df_list
# Out:
#    year          brand                                model         type  \
# 0  2016         Toyota                    Land Cruiser Base          SUV
# 1  2014            RAM  ProMaster 2500 Window Van High Roof          Van
# 2  2002           Ford                           Mustang GT        Coupe
# 3  2012            BMW              428 Gran Coupe i xDrive        Sedan
# 4  2008  Mercedes-Benz  SL-Class SL500 Roadster Convertible  Convertible
#
#    city_miles_per_gallon  highway_miles_per_gallon
# 0                     13                        18
# 1                     15                        20
# 2                     16                        22
# 3                     27                        34
# 4                     18                        25

# %%
df = pd.DataFrame(data)
df['brand']
# Out:
# 0           Toyota
# 1              RAM
# 2             Ford
# 3              BMW
# 4    Mercedes-Benz
# Name: brand, dtype: object

# %%
df[['year', 'brand', 'model']]
# Out:
#    year          brand                                model
# 0  2016         Toyota                    Land Cruiser Base
# 1  2014            RAM  ProMaster 2500 Window Van High Roof
# 2  2002           Ford                           Mustang GT
# 3  2012            BMW                       428 Gran Coupe
# 4  2008  Mercedes-Benz                       SL-Class SL500

# %%
single_row_loc = df.loc[2]
single_row_loc


multiple_rows_loc = df.loc[[1, 3, 4]]
multiple_rows_loc
# Out:
#    year          brand                                model         type  \
# 1  2014            RAM  ProMaster 2500 Window Van High Roof          Van
# 3  2012            BMW                       428 Gran Coupe        Sedan
# 4  2008  Mercedes-Benz                       SL-Class SL500  Convertible
#
#    city_miles_per_gallon  highway_miles_per_gallon
# 1                     15                        20
# 3                     27                        34
# 4                     18                        25
