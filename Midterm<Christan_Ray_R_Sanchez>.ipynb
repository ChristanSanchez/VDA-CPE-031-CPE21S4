# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristanSanchez/VDA-CPE-031-CPE21S4/blob/main/Midterm%3CChristan_Ray_R_Sanchez%3E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Heart 2022 with nans

# %%
import pandas as pd

df = pd.read_csv('heart_2022_with_nans.csv')

heart_cleaned = pd.DataFrame(df)

heart_cleaned
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 0              Alabama  Female     Very good                 0.0
# 1              Alabama  Female     Excellent                 0.0
# 2              Alabama  Female     Very good                 2.0
# 3              Alabama  Female     Excellent                 0.0
# 4              Alabama  Female          Fair                 2.0
# ...                ...     ...           ...                 ...
# 445127  Virgin Islands  Female          Good                 0.0
# 445128  Virgin Islands  Female     Excellent                 2.0
# 445129  Virgin Islands  Female          Poor                30.0
# 445130  Virgin Islands    Male     Very good                 0.0
# 445131  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 0                    0.0  Within past year (anytime less than 12 months ...
# ...

# %% [markdown]
# Familiarize yourself with the variables and observations using Pandas.
#
# - so first to familiarize myself with the the I will first print both the head and the tail of the dataframe

# %%
import pandas as pd

df = pd.read_csv('heart_2022_with_nans.csv')

heart_cleaned = pd.DataFrame(df)

heart_cleaned.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 No
# 1                                                NaN                 No
# 2  Within past year (anytime less than 12 months ...                Yes
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours RemovedTeeth HadHeartAttack  ... HeightInMeters  \
# ...

# %%
import pandas as pd

df = pd.read_csv('heart_2022_with_nans.csv')

heart_cleaned = pd.DataFrame(df)

heart_cleaned.tail()
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 445127  Virgin Islands  Female          Good                 0.0
# 445128  Virgin Islands  Female     Excellent                 2.0
# 445129  Virgin Islands  Female          Poor                30.0
# 445130  Virgin Islands    Male     Very good                 0.0
# 445131  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 445127               3.0  Within past 2 years (1 year but less than 2 ye...
# 445128               2.0  Within past year (anytime less than 12 months ...
# 445129              30.0                                5 or more years ago
# 445130               0.0  Within past year (anytime less than 12 months ...
# 445131               1.0                                                NaN
#
#        PhysicalActivities  SleepHours  RemovedTeeth HadHeartAttack  ...  \
# ...

# %% [markdown]
# as you can see I just recreated the whole csv into a dictionary making me more familiar with the data given

# %% [markdown]
# TWO QUESTIONS
#
# 1) Does Gender have any correlations with BMI?
#
# 2) Does state have any significance with Alchohol Drinkers?

# %% [markdown]
# Does Gender have any correlations with BMI?

# %%
avg_bmi_by_gender = df.groupby('Sex')['BMI'].mean()

plt.figure(figsize=(8, 6))
avg_bmi_by_gender.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title("Average BMI by Gender")
plt.xlabel("Gender")
plt.ylabel("Average BMI")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# OBSERVATION: Based on the data given, there is a relationship between gender and BMI.
#
# Based on the bar chart of Average BMI by Gender:
# It shows that males and females have differing average BMI values, indicating that gender may influence BMI.
# Conclusion: There appears to be a correlation between gender and BMI in this dataset, with one gender possibly having a higher average BMI than the other. In my opinion, considering gender when evaluating BMI can help address specific health concerns.

# %% [markdown]
#  Does Sleeping hours have any significance with Overall General  Health?

# %%
alcohol_state_counts = df.groupby(['State', 'AlcoholDrinkers']).size().unstack(fill_value=0)

alcohol_state_counts.plot(kind='bar', figsize=(10, 6), color=['lightgreen', 'lightcoral'])
plt.title("Count of Alcohol Drinkers by State")
plt.xlabel("State")
plt.ylabel("Count of Alcohol Drinkers")
plt.xticks(rotation=45)
plt.legend(title="Alcohol Drinkers", labels=["Yes", "No"], loc='upper right')
plt.show()

# %% [markdown]
# OBSERVATION: Based on the data given, we can evaluate the significance of state on alcohol consumption.
#
# Based on the bar chart of Alcohol Drinkers by State:
# It shows the count of individuals who drink alcohol ("Yes" or "No") across different states, highlighting regional differences in alcohol consumption.
# Conclusion: The distribution of alcohol drinkers by state suggests potential cultural or regulatory influences on alcohol consumption. In my opinion, understanding these patterns can help in addressing public health initiatives related to alcohol use.

# %% [markdown]
# # Heart 2022 with No nans

# %%
import pandas as pd

df = pd.read_csv('heart_2022_no_nans.csv')

heart_cleaned = pd.DataFrame(df)

heart_cleaned
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 0              Alabama  Female     Very good                 4.0
# 1              Alabama    Male     Very good                 0.0
# 2              Alabama    Male     Very good                 0.0
# 3              Alabama  Female          Fair                 5.0
# 4              Alabama  Female          Good                 3.0
# ...                ...     ...           ...                 ...
# 246017  Virgin Islands    Male     Very good                 0.0
# 246018  Virgin Islands  Female          Fair                 0.0
# 246019  Virgin Islands    Male          Good                 0.0
# 246020  Virgin Islands  Female     Excellent                 2.0
# 246021  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 0                    0.0  Within past year (anytime less than 12 months ...
# ...

# %% [markdown]
# Familiarize yourself with the variables and observations using Pandas.
#
# - so first to familiarize myself with the the I will first print both the head and the tail of the dataframe

# %%
import pandas as pd

df = pd.read_csv('heart_2022_no_nans.csv')

heart_cleaned = pd.DataFrame(df)

heart_cleaned.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 4.0               0.0
# 1  Alabama    Male     Very good                 0.0               0.0
# 2  Alabama    Male     Very good                 0.0               0.0
# 3  Alabama  Female          Fair                 5.0               0.0
# 4  Alabama  Female          Good                 3.0              15.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                Yes
# 1  Within past year (anytime less than 12 months ...                Yes
# 2  Within past year (anytime less than 12 months ...                 No
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours            RemovedTeeth HadHeartAttack  ... HeightInMeters  \
# ...

# %%
import pandas as pd

df = pd.read_csv('heart_2022_no_nans.csv')

heart_cleaned = pd.DataFrame(df)

heart_cleaned.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 4.0               0.0
# 1  Alabama    Male     Very good                 0.0               0.0
# 2  Alabama    Male     Very good                 0.0               0.0
# 3  Alabama  Female          Fair                 5.0               0.0
# 4  Alabama  Female          Good                 3.0              15.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                Yes
# 1  Within past year (anytime less than 12 months ...                Yes
# 2  Within past year (anytime less than 12 months ...                 No
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours            RemovedTeeth HadHeartAttack  ... HeightInMeters  \
# ...

# %% [markdown]
# TWO QUESTIONS
#
# 1) Is there a relationship between General Health and Mental Health Days?
#
# 2) What is the relationship between Physical Activities and Alcohol Drinkers?

# %% [markdown]
#  Is there a relationship between General Health and Mental Health Days?

# %%
df['GeneralHealthNumeric'] = df['GeneralHealth'].map(health_mapping)


plt.figure(figsize=(10, 6))
plt.scatter(df['MentalHealthDays'], df['GeneralHealthNumeric'], color='blue', alpha=0.6)
plt.title("Relationship between Mental Health Days and General Health")
plt.xlabel("Mental Health Days")
plt.ylabel("General Health Rating (Numeric)")
plt.xticks(rotation=0)
plt.show()


correlation = df[['MentalHealthDays', 'GeneralHealthNumeric']].corr().iloc[0, 1]
print(f"Correlation between Mental Health Days and General Health: {correlation}")
# Out:
# Correlation between Mental Health Days and General Health: -0.2685385052187404

# %% [markdown]
# OBSERVATION: Based on the data given, we can evaluate the relationship between general health and mental health days.
#
# Based on the scatter plot of Mental Health Days vs. General Health:
# It shows how the number of mental health days correlates with the general health rating, allowing us to see patterns in health perception.
# Conclusion: The correlation suggests that more mental health days may be associated with better general health ratings. In my opinion, addressing mental health is crucial for overall well-being.

# %% [markdown]
#  What is the relationship between Physical Activities and Alcohol Drinkers?

# %%
activity_alcohol_counts = df.groupby(['PhysicalActivities', 'AlcoholDrinkers']).size().unstack(fill_value=0)


activity_alcohol_counts.plot(kind='bar', figsize=(10, 6), color=['lightgreen', 'lightcoral'])
plt.title("Count of Alcohol Drinkers by Physical Activities")
plt.xlabel("Physical Activity Level")
plt.ylabel("Count of Alcohol Drinkers")
plt.xticks(rotation=0)
plt.legend(title="Alcohol Drinkers", labels=["Yes", "No"], loc='upper right')
plt.show()


print(activity_alcohol_counts)
# Out:
# AlcoholDrinkers        No     Yes
# PhysicalActivities
# No                  32651   22053
# Yes                 78064  113254

# %% [markdown]
# OBSERVATION: Based on the data given, we can evaluate the relationship between physical activities and alcohol consumption.
#
# Based on the bar chart of Alcohol Drinkers by Physical Activities:
# It shows the count of individuals who drink alcohol ("Yes" or "No") across different levels of physical activity, highlighting how active individuals perceive their alcohol consumption.
# Conclusion: The distribution indicates that physical activity levels may influence alcohol consumption patterns. In my opinion, promoting physical activity could help reduce alcohol consumption rates in the community.
